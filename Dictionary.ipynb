# %% [markdown]
# # Dictionary

# %%
#dictionary
d1={}
print(type(d1))
# Out:
# <class 'dict'>

# %%
d2=dict()
print(type(d2))
# Out:
# <class 'dict'>

# %%
d3={1:'ram',2:'sham',3:'jay',4:'vijay'}
d3
# Out:
# {1: 'ram', 2: 'sham', 3: 'jay', 4: 'vijay'}

# %%
d3[2]
# Out:
# 'sham'

# %%
d3[4]="om"

# %%
d3
# Out:
# {1: 'ram', 2: 'sham', 3: 'jay', 4: 'om'}

# %%
d3[5]='ajay'
print(d3)
# Out:
# {1: 'ram', 2: 'sham', 3: 'jay', 4: 'om', 5: 'ajay'}

# %%
d3.update({4:'sachin'})
d3
# Out:
# {1: 'ram', 2: 'sham', 3: 'jay', 4: 'sachin', 5: 'ajay'}

# %%
d3.popitem()
# Out:
# (5, 'ajay')

# %%
d3.pop(4)
# Out:
# 'sachin'

# %%
del d3[2]

# %%
d3.clear()

# %%
d3.keys()
# Out:
# dict_keys([])

# %%
d3.values()
# Out:
# dict_values([])

# %%
d4={1:'anjali',2:'sakshi'}
d4
# Out:
# {1: 'anjali', 2: 'sakshi'}

# %%
d4.keys()
# Out:
# dict_keys([1, 2])

# %%
d4.values()
# Out:
# dict_values(['anjali', 'sakshi'])

# %%
d4.items()
# Out:
# dict_items([(1, 'anjali'), (2, 'sakshi')])

# %%
d4[2]
# Out:
# 'sakshi'

# %%
d4.clear()
print(d4)
# Out:
# {}

# %%
v=[0,1,2,3,[8,{5:[67,89,90,{'area':'kudlu','city':'banglore'}]}]]

# %%
v
# Out:
# [0, 1, 2, 3, [8, {5: [67, 89, 90, {'area': 'kudlu', 'city': 'banglore'}]}]]

# %%
v[-1][-1][5][-1]['city']
# Out:
# 'banglore'
