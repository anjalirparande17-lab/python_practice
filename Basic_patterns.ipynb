# %%
#pattern1:square
print("* * *")
print("* * *")
print("* * *")
# Out:
# * * *
# * * *
# * * *

# %%
#pattern2:triangle
print("*")
print("* *")
print("* * *")
# Out:
# *
# * *
# * * *

# %%
#pattern3:reverse triangle
print("* * *")
print("* *")
print("*")
# Out:
# * * *
# * *
# *

# %%
#pattern4:numbers
print("1")
print("1 2")
print("1 2 3")
# Out:
# 1
# 1 2
# 1 2 3

# %%
#pattern5:reverse numbers
print("1 2 3")
print("1 2")
print("1")
# Out:
# 1 2 3
# 1 2
# 1

# %%
#pattern6:Alphabets
print("A")
print("A B")
print("A B C")
# Out:
# A
# A B
# A B C

# %%
#pattern7:Stars
print("*")
print("* *")
print("* * *")
print("* * * *")
# Out:
# *
# * *
# * * *
# * * * *

# %%
#pattern8:Rectangle
print("*****")
print("*****")
print("*****")
# Out:
# *****
# *****
# *****
