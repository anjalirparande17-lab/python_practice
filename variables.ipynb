# %%
#program1:Store and print a name
name=("Anjali")
print(name)
# Out:
# Anjali

# %%
#program2:Store and print age
age=21
print(age)
# Out:
# 21

# %%
#prgram3:Store and print city name
City='pune'
print(City)
# Out:
# pune

# %%
#program4:store and print marks
marks=96
print(marks)
# Out:
# 96

# %%
#program5:store and print decimal value
height=5.6
print(height)
# Out:
# 5.6

# %%
#program6:print multiple variables
name="Anjali"
age=21
city="pune"

# %%
print(name)
print(age)
print(city)
# Out:
# Anjali
# 21
# pune

# %%
#program7:print variable with text
name="Anjali"
course="python programming"

# %%
print("name:",name)
print("course:",course)
# Out:
# name: Anjali
# course: python programming

# %%
#program8:Addition using variables
a=20
b=30 
c=a+b
print(c)
# Out:
# 50

# %%
#program9:multiplication using variables
a=10
b=40
mul=a*b
print("result=",mul)
# Out:
# result= 400

# %%
#program10:swap two variables
a=10
b=20
temp=a
a=b
b=temp
print("a=",a)
print("b=",b)
# Out:
# a= 20
# b= 10
