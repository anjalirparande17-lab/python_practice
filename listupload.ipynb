# %% [markdown]
# # list

# %%
#creation of list
l1=[10,20,30,40,50,60,50,20]

# %%
#type check
type(l1)
# Out:
# list

# %%
# ---------------------------methods-------------------------
#accessing elements
l1[3]
# Out:
# 40

# %%
#list slicing
l1[0:7]
# Out:
# [10, 20, 30, 40, 50, 60, 50]

# %%
#takes range with a step(jump)->2
l1[::2]
# Out:
# [10, 30, 50, 50]

# %%
#Range of elements in list
l1[:]
# Out:
# [10, 20, 30, 40, 50, 60, 50, 20]

# %%
#reverse a list
l1[::-1]
# Out:
# [20, 50, 60, 50, 40, 30, 20, 10]

# %%
#printing list
l1
# Out:
# [10, 20, 30, 40, 50, 60, 50, 20]

# %%
#adding element at last 
l1.append(200)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 50, 20, 200]

# %%
#inserting element at the given position
l1.insert(3,25)

# %%
l1
# Out:
# [10, 20, 30, 25, 40, 50, 60, 50, 20, 200]

# %%
#Add entire object as one element
l1.append([100,200,300])

# %%
l1
# Out:
# [10, 20, 30, 25, 40, 50, 60, 50, 20, 200, [100, 200, 300]]

# %%
#add one element in the list one by one
l1.extend([400,500,600])

# %%
l1
# Out:
# [10, 20, 30, 25, 40, 50, 60, 50, 20, 200, [100, 200, 300], 400, 500, 600]

# %%
l1
# Out:
# [10, 20, 30, 25, 40, 50, 60, 50, 20, 200, [100, 200, 300], 400, 500, 600]

# %%
#remove elements throgh index
l1.pop(1)
# Out:
# 20

# %%
l1
# Out:
# [10, 30, 25, 40, 50, 60, 50, 20, 200, [100, 200, 300], 400, 500, 600]

# %%
#remove element directly 
l1.remove(25)

# %%
#deletes elements throght index
del l1[-1]

# %%
l1
# Out:
# [10, 30, 40, 50, 60, 50, 20, 200, [100, 200, 300], 400, 500]

# %%
#-------------------functions--------------
len(l1)
# Out:
# 11

# %%
print(l1)
# Out:
# [10, 30, 40, 50, 60, 50, 20, 200, [100, 200, 300], 400, 500]

# %%
#determines length
len(l1)
# Out:
# 11

# %%
#keyword del
del l1[8]

# %%
l1
# Out:
# [10, 30, 40, 50, 60, 50, 20, 200, 400, 500]

# %%
#fuunction
sorted(l1)
# Out:
# [10, 20, 30, 40, 50, 50, 60, 200, 400, 500]

# %%
#reverse sorted
sorted (l1,reverse=True)
# Out:
# [500, 400, 200, 60, 50, 50, 40, 30, 20, 10]

# %%
#adding element through index
l1.insert(1,20)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 50, 20, 200, 400, 500]

# %%
#adding element at the end of the list
l1.append([100,200,300])

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 50, 20, 200, 400, 500, [100, 200, 300]]

# %%
#removing element throght index
l1.pop(-1)
# Out:
# [100, 200, 300]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 50, 20, 200, 400, 500]

# %%
#add multiple element at the end of the  list
l1.extend([300,400])

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 50, 20, 200, 400, 500, 300, 400]

# %%
#all = checks weather every value is true-(positive values)
all(l1)
# Out:
# True

# %%
l1.append(0)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 50, 20, 200, 400, 500, 300, 400, 0]

# %%
all(l1)
# Out:
# False

# %%
l1[-1]=1

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 50, 20, 200, 400, 500, 300, 400, 1]

# %%
del l1[-1]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 50, 20, 200, 400, 500, 300, 400]

# %%
#in-accesing through elements are present in list or not
20 in l1
# Out:
# True

# %%
23 in l1
# Out:
# False
