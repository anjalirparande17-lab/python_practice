# %% [markdown]
# # Tuple

# %%
#--------------tuple-----------------
t1=()
type(t1)
# Out:
# tuple

# %%
print(type(t1))
# Out:
# <class 'tuple'>

# %%
#creation of tuple
t1=(1,2,3,4,56,5,6,7,8,9,9,9)

# %%
t1
# Out:
# (1, 2, 3, 4, 56, 5, 6, 7, 8, 9, 9, 9)

# %%
#accessing element through index
t1[3]
# Out:
# 4

# %%
t1[-1]
# Out:
# 9

# %%
len(t1)
# Out:
# 12

# %%
#counts element occurance
t1.count(9)
# Out:
# 3

# %%
#slicing element based on steps
t1[0:11:2]
# Out:
# (1, 3, 56, 6, 8, 9)

# %%
#sorting
sorted(t1)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 9, 9, 56]

# %%
t1[:]
# Out:
# (1, 2, 3, 4, 56, 5, 6, 7, 8, 9, 9, 9)

# %%
#removes element from last
t1[:-1]
# Out:
# (1, 2, 3, 4, 56, 5, 6, 7, 8, 9, 9)

# %%
#reverse tuple
t1[::-1]
# Out:
# (9, 9, 9, 8, 7, 6, 5, 56, 4, 3, 2, 1)

# %%
t1
# Out:
# (1, 2, 3, 4, 56, 5, 6, 7, 8, 9, 9, 9)

# %%
#tuples are immutable so this operations can not perfrom(run)......

# %%
t1.append(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 t1.append(10)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1.insert(-1,100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 t1.insert(-1,100)
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
t1.extend(100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 t1.extend(100)
#
# AttributeError: 'tuple' object has no attribute 'extend'

# %%
t1.pop(-1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 t1.pop(-1)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t1
# Out:
# (1, 2, 3, 4, 56, 5, 6, 7, 8, 9, 9, 9)

# %%
t1.remove(56)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 t1.remove(56)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
del t1[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 del t1[2]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
t1
# Out:
# (1, 2, 3, 4, 56, 5, 6, 7, 8, 9, 9, 9)

# %%
3 in t1
# Out:
# True

# %%
33 in t1
# Out:
# False

# %%
t1(-1)==90
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 t1(-1)==90
#
# TypeError: 'tuple' object is not callable
