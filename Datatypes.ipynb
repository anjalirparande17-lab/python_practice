# %%
#integer 
age=20
print("integer:",age)
# Out:
# integer: 20

# %%
#float
height=5.6
print("float:",height)
# Out:
# float: 5.6

# %%
#string
name="anjali"
print("string:",name)
# Out:
# string: anjali

# %%
#boolean
is_student=True
print("boolean:",is_student)
# Out:
# boolean: True

# %%
#list
fruits= ["Apples","Banana","Mango"]
print("List",fruits)
# Out:
# List ['Apples', 'Banana', 'Mango']

# %%
#tuple
colors=("red","green","blue")
print("tuple:",colors)
# Out:
# tuple: ('red', 'green', 'blue')

# %%
#set
numbers={1,2,4,5,8}
print("set",numbers)
# Out:
# set {1, 2, 4, 5, 8}

# %%
#dictionary
student={
    "name": "Anjali",
    "age":20,
    "course":"python"
}
print("Dictionary:",student)
# Out:
# Dictionary: {'name': 'Anjali', 'age': 20, 'course': 'python'}

# %%
#none type
value=None
print("none",value)
# Out:
# none None
