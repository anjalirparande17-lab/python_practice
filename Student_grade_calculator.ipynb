# %% [markdown]
# # Student Grade Calculator

# %%
print("===== STUDENT GRADE CALCULATOR =====")

name = input("Enter student name: ")

subjects = ['Python', 'SQL', 'Statistics', 'Power BI', 'Machine Learning']

marks = []

# Enter marks
for subject in subjects:
    while True:
        try:
            mark = float(input(f"Enter marks for {subject}: "))

            if 0 <= mark <= 100:
                marks.append(mark)
                break
            else:
                print("Marks must be between 0 and 100.")

        except ValueError:
            print("Please enter a valid number.")


# Calculate total and percentage
total = sum(marks)
percentage = total / len(subjects)


# Grade calculation
if percentage >= 90:
    grade = "A+"
elif percentage >= 80:
    grade = "A"
elif percentage >= 70:
    grade = "B"
elif percentage >= 60:
    grade = "C"
elif percentage >= 50:
    grade = "D"
else:
    grade = "F"


# Pass or Fail
if percentage >= 40:
    result = "PASS"
else:
    result = "FAIL"


# Display result
print("\n===== RESULT =====")
print("Student Name:", name)
print("Total Marks:", total, "/ 500")
print("Percentage:", percentage, "%")
print("Grade:", grade)
print("Result:", result)
print("\nHighest Marks:", max(marks))
print("Lowest Marks:", min(marks))
# Out:
# ===== STUDENT GRADE CALCULATOR =====
# Enter student name:  Anjali
# Enter marks for Python:  98
# Enter marks for SQL:  67
# Enter marks for Statistics:  88
# Enter marks for Power BI:  77
# Enter marks for Machine Learning:  97
# ===== RESULT =====
# Student Name: Anjali
# Total Marks: 427.0 / 500
# Percentage: 85.4 %
# Grade: A
# Result: PASS
#
# Highest Marks: 98.0
# Lowest Marks: 67.0
